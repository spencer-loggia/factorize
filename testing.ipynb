# %%
from CSForaging import ColorShapeForage

# %%
env = ColorShapeForage()

# %%
env.plot_freq_space()

# %%
env.plot_reward_space()

# %%
env.reset()
# Out:
# (array([ 0.17364818,  0.98480775, -0.64278761,  0.76604444,  0.5       ,
#          0.8660254 ,  0.76604444,  0.64278761,  0.17364818,  0.98480775,
#          0.98480775, -0.17364818, -0.5       , -0.8660254 , -0.98480775,
#          0.17364818]),
#  {})

# %%
env.step(2)
# Out:
# (array([ 1.00000000e+00,  6.12323400e-17,  6.42787610e-01,  7.66044443e-01,
#          5.00000000e-01, -8.66025404e-01, -5.00000000e-01,  8.66025404e-01,
#          8.66025404e-01,  5.00000000e-01,  9.39692621e-01,  3.42020143e-01,
#         -6.42787610e-01,  7.66044443e-01, -9.84807753e-01,  1.73648178e-01]),
#  -1,
#  False,
#  False,
#  {})
